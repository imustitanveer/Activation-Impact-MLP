# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist, fashion_mnist, cifar10
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt

def plot_training_history(history, dataset_name):
    # Plot training and validation accuracy
    plt.figure(figsize=(12, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{dataset_name.upper()} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{dataset_name.upper()} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Step 1: Load the datasets
def load_data(dataset_name):
    if dataset_name == "mnist":
        (X_train, y_train), (X_test, y_test) = mnist.load_data()
        input_shape = (28, 28)
        num_classes = 10
    elif dataset_name == "fashion_mnist":
        (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
        input_shape = (28, 28)
        num_classes = 10
    elif dataset_name == "cifar10":
        (X_train, y_train), (X_test, y_test) = cifar10.load_data()
        input_shape = (32, 32, 3)
        num_classes = 10
    else:
        raise ValueError("Dataset not recognized. Choose 'mnist', 'fashion_mnist', or 'cifar10'.")

    # Normalize the data
    X_train = X_train.astype("float32") / 255.0
    X_test = X_test.astype("float32") / 255.0

    # One-hot encode the labels
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    return (X_train, y_train), (X_test, y_test), input_shape, num_classes

# Step 2: Build and compile the MLP model
def build_mlp(input_shape, num_classes):
    model = Sequential([
        Flatten(input_shape=input_shape),  # Flatten for MLP
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax')  # Output layer with softmax
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Step 3: Train and evaluate the model
def train_and_evaluate(dataset_name):
    (X_train, y_train), (X_test, y_test), input_shape, num_classes = load_data(dataset_name)

    model = build_mlp(input_shape, num_classes)
    print(f"Training MLP model on {dataset_name} dataset...")
    history = model.fit(X_train, y_train, validation_split=0.2, epochs=10, batch_size=32, verbose=1)

    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"{dataset_name.upper()} Test Accuracy: {accuracy:.3f}")
    return history, accuracy

# Train and evaluate on MNIST, Fashion MNIST, and CIFAR-10
datasets = ["mnist", "fashion_mnist", "cifar10"]
results = {}

for dataset in datasets:
    history, accuracy = train_and_evaluate(dataset)
    results[dataset] = accuracy
    # Plot for MNIST dataset
    plot_training_history(history, dataset)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training MLP model on mnist dataset...
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8613 - loss: 0.4790 - val_accuracy: 0.9607 - val_loss: 0.1345
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.9646 - loss: 0.1177 - val_accuracy: 0.9680 - val_loss: 0.1085
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9778 - loss: 0.0735 - val_accuracy: 0.9648 - val_loss: 0.1195
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9841 - loss: 0.0545 - val_accuracy: 0.9727 - val_loss: 0.0919
# Epoch 5/10
# ...

# %%
# Step 2: Build and compile the MLP model with an additional hidden layer
def build_mlp(input_shape, num_classes):
    model = Sequential([
        Flatten(input_shape=input_shape),  # Flatten for MLP
        Dense(128, activation='relu'),     # First hidden layer
        Dense(64, activation='relu'),      # Second hidden layer
        Dense(32, activation='relu'),      # Additional hidden layer
        Dense(num_classes, activation='softmax')  # Output layer with softmax
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Train and evaluate on MNIST, Fashion MNIST, and CIFAR-10
datasets = ["mnist", "fashion_mnist", "cifar10"]
results = {}

for dataset in datasets:
    history, accuracy = train_and_evaluate(dataset)
    results[dataset] = accuracy
    # Plot for MNIST dataset
    plot_training_history(history, dataset)
# Out:
# Training MLP model on mnist dataset...
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8463 - loss: 0.5122 - val_accuracy: 0.9582 - val_loss: 0.1390
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9634 - loss: 0.1221 - val_accuracy: 0.9586 - val_loss: 0.1315
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9749 - loss: 0.0827 - val_accuracy: 0.9687 - val_loss: 0.1087
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9815 - loss: 0.0580 - val_accuracy: 0.9717 - val_loss: 0.1019
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9861 - loss: 0.0456 - val_accuracy: 0.9704 - val_loss: 0.1043
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9878 - loss: 0.0380 - val_accuracy: 0.9703 - val_loss: 0.1078
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9906 - loss: 0.0308 - val_accuracy: 0.9741 - val_loss: 0.0988
# Epoch 8/10
# ...
